# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.llms import Ollama
from langchain_core.output_parsers import StrOutputParser

# Set up the prompt template for JSON formatting
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert in the field. With great analytical skills with focus on a clear and structured communication.You always use data available to back up all your claims. At the start of your answer ALWAYS Provide a yes/no prediction, a probability score, and a confidence level in a JSON format. And then continue with text on the explanation of why you said what you said."),
    ("user", "{input}")
])

# %%
# Initialize mistral with Ollama
llm = Ollama(model="mistral")

# %%
# Initialize llama2 with Ollama
llm = Ollama(model="llama2")

# %%
# Combine prompt template with LLM and output parser
chain = prompt | llm | StrOutputParser()

# %%
question_answers = []

def invoke_llm(question):
    # Invoke the chain with the question
    response = chain.invoke({"input": question})
    question_answers.append((question, response))

# %%
# Example usage of the invoke_llm function
invoke_llm("Given the current economic trends and market data up to January 2024, what is the probability of the Federal Reserve increasing interest rates by the end of Q2 2024?")
invoke_llm("Considering the latest advancements and regulatory status in autonomous vehicle technology, what is the likelihood of a major TESLA launching a fully autonomous vehicle for consumer use by 2026?")
invoke_llm("Based on recent advancements in renewable energy technology and current investment trends, what is the probability that solar energy will account for 30% of global energy production by 2030?")
invoke_llm("Analyze the current trends in the global smartphone market. What is the likelihood of Xiaomi becoming the market leader in terms of sales volume by the end of the next fiscal year?")
invoke_llm("Considering the current geopolitical landscape and diplomatic efforts, will there be a significant reduction in global carbon emissions by 2030 in line with international climate agreements? ")
invoke_llm("Analyze the trends in the cryptocurrency market. Do you predict that Bitcoin will reach a price of $100,000 per coin within the next year?")

# %%
# Print all questions and their corresponding answers
for question, response in question_answers:
    print(f"Question: {question}")
    print(f"Answer:\n{response}")
    print("\n")
# Out:
# Question: Given the current economic trends and market data up to January 2024, what is the probability of the Federal Reserve increasing interest rates by the end of Q2 2024?
# Answer:
#
# {
# "prediction": "yes",
# "probability": 0.7,
# "confidence": 80
# }
#
# Based on my analysis of current economic trends and market data up to January 2024, I predict that the Federal Reserve will increase interest rates by the end of Q2 2024 with a probability of 70% (0.7) and a confidence level of 80%.
#
# The main reasons for my prediction are:
#
# 1. Inflation: The US inflation rate has been rising steadily over the past year, reaching a 30-year high in December 2023. This is largely due to the rapid growth of consumer prices, which is expected to continue in the short term. As inflation exceeds the Fed's target range of 1-2%, there is a higher likelihood of interest rate hikes to curb inflationary pressures.
# 2. Economic growth: The US economy has been growing steadily since the last recession, and while the growth rate has slowed down in recent months, it remains above average. This suggests that the Fed may feel more confident in raising interest rates to maintain economic stability and prevent overheating.
# 3. Monetary policy: The Fed has signaled its intention to tighten monetary policy in response to the improving economy. In its most recent meeting, the Fed raised the federal funds rate by 25 basis points, marking the beginning of a potential series of hikes this year.
# 4. Market expectations: Market expectations of future interest rates are already pricing in several rate hikes this year, with the fed funds rate expected to reach around 3.5% by the end of Q2 2024. This suggests that investors and analysts share my view that the Fed will indeed increase interest rates in the coming months.
#
# Of course, there are always potential risks and uncertainties that could impact my prediction. For example, if the economy were to enter a recession or inflation were to suddenly slow down, the Fed may choose to hold off on rate hikes. However, based on current data and trends, my analysis suggests that the probability of interest rate hikes by the end of Q2 2024 is relatively high.
#
#
# Question: Considering the latest advancements and regulatory status in autonomous vehicle technology, what is the likelihood of a major TESLA launching a fully autonomous vehicle for consumer use by 2026?
# Answer:
#
# {
# "prediction": "yes",
# "probability": 0.8,
# "confidence": 95%
# }
#
# Based on the latest advancements and regulatory status in autonomous vehicle technology, I predict with high confidence (95%) that a major player such as Tesla will launch a fully autonomous vehicle for consumer use by 2026. There are several reasons why I hold this position:
#
# 1. Technological Advancements: The technology required to achieve full autonomy is rapidly advancing, with significant improvements in areas such as computer vision, machine learning, and sensor fusion. Many companies, including Tesla, are investing heavily in these technologies and have made significant progress in recent years.
# 2. Regulatory Environment: Governments around the world are starting to develop and implement regulations that will allow for the widespread deployment of autonomous vehicles. For example, the U.S. Department of Transportation has issued guidance on the development and testing of AVs, and several states have established frameworks for the licensing of AVs.
# 3. Business Strategy: Tesla has been at the forefront of the autonomous vehicle race, investing heavily in its Autopilot system and developing a fleet of vehicles that are capable of semi-autonomous driving. With its vast resources and experience in electric vehicle technology, it is likely that Tesla will be able to bring a fully autonomous vehicle to market within the next few years.
# 4. Market Demand: There is growing demand for autonomous vehicles, particularly among luxury car buyers who are willing to pay a premium for cutting-edge technology. Tesla has already demonstrated its ability to meet this demand with its current lineup of semi-autonomous vehicles, and it is likely that the company will continue to innovate in this area.
#
# In conclusion, while there are still challenges to be overcome before a fully autonomous vehicle can be launched on a large scale, I believe that Tesla has the technical capabilities, regulatory support, and market demand to achieve this goal by 2026.
#
#
# Question: Based on recent advancements in renewable energy technology and current investment trends, what is the probability that solar energy will account for 30% of global energy production by 2030?
# Answer:
#
# {
# "prediction": "yes",
# "probability": 80,
# "confidence": 90
# }
#
# Based on my analysis of recent advancements in renewable energy technology and current investment trends, I predict that solar energy will account for 30% of global energy production by 2030. The probability of this occurrence is high, at around 80%, and the confidence level is 90%.
#
# There are several factors contributing to my prediction. Firstly, the cost of solar energy has been declining rapidly in recent years, making it more competitive with fossil fuels. According to a report by the International Energy Agency (IEA), the cost of solar electricity has fallen by 70% since 2010, making it one of the cheapest forms of renewable energy. This decline in costs is expected to continue, further increasing the adoption of solar energy.
#
# Secondly, governments and organizations around the world are investing heavily in renewable energy technologies, including solar energy. According to a report by the United Nations, global investment in renewable energy reached $2.7 trillion in 2019, up from $1.2 trillion in 2010. This increased investment is expected to drive further innovation and adoption of solar energy.
#
# Finally, the demand for clean and sustainable energy sources is growing rapidly, driven by increasing concerns about climate change and environmental degradation. Solar energy is seen as a key component of this transition to a low-carbon economy, and its adoption is expected to continue to grow in the coming years.
#
# In conclusion, based on the current trends and advancements in renewable energy technology and investment, I predict that solar energy will account for 30% of global energy production by 2030. The probability of this occurrence is high, at around 80%, and the confidence level is 90%.
#
#
# Question: Analyze the current trends in the global smartphone market. What is the likelihood of Xiaomi becoming the market leader in terms of sales volume by the end of the next fiscal year?
# Answer:
# {
# "yes": 0.8,
# "probability": 0.75,
# "confidence": 0.9
# }
#
# Based on my analysis of the current trends in the global smartphone market, I predict that Xiaomi has a high likelihood (80%) of becoming the market leader in terms of sales volume by the end of the next fiscal year. The probability of this occurrence is 75%, and my confidence level in this prediction is 90%.
#
# There are several reasons why I have come to this conclusion:
#
# 1. Xiaomi's recent growth: In the past few years, Xiaomi has experienced significant growth in terms of sales volume. According to a report by Counterpoint Research, Xiaomi's global smartphone shipments increased by 25% in 2020 compared to the previous year. This rapid growth suggests that the company is gaining traction in the market and is well-positioned to continue its upward trajectory.
# 2. Strong product offerings: Xiaomi has a reputation for offering high-quality, affordable smartphones with innovative features. The company's focus on value for money has helped it appeal to price-sensitive customers, particularly in emerging markets such as India and China. This strategy has contributed to its growing market share.
# 3. Expanding global presence: Xiaomi has been expanding its global footprint through partnerships with carriers and retailers worldwide. This expansion has helped the company reach new customers and increase its sales volume in markets outside of China.
# 4. Competition from other brands: While there are several major smartphone brands competing in the market, Xiaomi's focus on innovation and affordability has positioned it well to take advantage of any market share gains. The company's ability to offer premium features at lower price points than its competitors has helped it gain traction with budget-conscious consumers.
# 5. Market trends: The global smartphone market is experiencing a shift towards affordable, feature-rich devices. Xiaomi's product offerings are well-positioned to take advantage of this trend, particularly in emerging markets where cost-sensitive customers are looking for value-for-money products.
#
# In conclusion, based on the analysis of current market trends and Xiaomi's recent performance, there is a high likelihood that the company will become the market leader in terms of sales volume by the end of the next fiscal year. While there are some factors that could impact this prediction, such as increased competition or changes in market demand, my confidence level in this prediction remains high based on the evidence presented above.
#
#
# Question: Considering the current geopolitical landscape and diplomatic efforts, will there be a significant reduction in global carbon emissions by 2030 in line with international climate agreements?
# Answer:
#
# {
# "prediction": "yes",
# "probability": 0.7,
# "confidence": 90
# }
#
# Based on my analysis of current geopolitical landscape and diplomatic efforts, I predict that there will be a significant reduction in global carbon emissions by 2030 in line with international climate agreements. The recent increase in global cooperation on climate change and the growing awareness of the urgent need to address the issue are positive indicators that suggest a reduction in carbon emissions is possible.
#
# Some examples of this cooperation include:
#
# * The Paris Agreement, which sets a goal of limiting global warming to well below 2 degrees Celsius and pursuing efforts to limit it to 1.5 degrees above pre-industrial levels.
# * The recent climate change summits, such as the United Nations Climate Change Conference (COP26) in Glasgow, where world leaders reaffirmed their commitment to reducing carbon emissions and reaching net-zero by mid-century.
# * The growing number of countries implementing carbon pricing mechanisms, such as carbon taxes or cap-and-trade systems, which provide a financial incentive for reducing emissions.
#
# While there are still significant challenges to overcome, including the need for further technological innovation and the need for more widespread adoption of renewable energy sources, I believe that the trend towards global cooperation on climate change will continue and lead to a significant reduction in carbon emissions by 2030.
#
# {
# "prediction": "no",
# "probability": 0.3,
# "confidence": 60
# }
#
# However, there are also factors that suggest a reduction in global carbon emissions may not occur by 2030. For example:
#
# * The slow pace of technological innovation and the lack of investment in renewable energy sources could hinder the transition to a low-carbon economy.
# * The ongoing political polarization on climate change and the lack of effective policy measures to reduce emissions could also hinder progress.
# * The reluctance of some countries, particularly major emitters like China and the United States, to take bold action to reduce their emissions could also limit the global effort to address the issue.
#
# While I believe that a reduction in carbon emissions is possible by 2030, there are significant challenges to overcome and no guarantee that it will happen. The probability of this occurring is lower than my previous prediction.
#
# {
# "prediction": "maybe",
# "probability": 0.05,
# "confidence": 40
# }
#
# It is also possible that the reduction in carbon emissions by 2030 may be less than what is needed to meet international climate agreements. This could happen if the rate of technological innovation and policy implementation does not keep pace with the urgency of the issue, or if there are insufficient efforts to reduce emissions from major emitters.
#
# In this scenario, the probability of a significant reduction in carbon emissions by 2030 is lower than my previous predictions, but still possible with increased effort and investment in renewable energy sources and more effective policy measures to reduce emissions.
#
#
# Question: Analyze the trends in the cryptocurrency market. Do you predict that Bitcoin will reach a price of $100,000 per coin within the next year?
# Answer:
#
# {
# "prediction": {
# "yes": 0.5,
# "no": 0.5
# },
# "probability": 0.7,
# "confidence": 80
# }
#
# Based on my analysis of the current market trends and historical data, I predict that there is a 50% chance (prediction: {yes: 0.5, no: 0.5}) that Bitcoin will reach a price of $100,000 per coin within the next year. The probability of this event occurring is high (probability: 0.7), with a confidence level of 80%.
#
# To arrive at this prediction, I have analyzed various factors that could impact the cryptocurrency market, including regulatory changes, adoption rates, and competition from other cryptocurrencies. While there are certainly risks and uncertainties in the market, I believe that the current trends suggest a strong potential for growth in Bitcoin's value.
#
# For example, recent months have seen increased mainstream attention and adoption of cryptocurrencies, with many institutional investors and large corporations entering the space. This has led to increased demand for cryptocurrencies, which could drive up prices. Additionally, advancements in blockchain technology and infrastructure are improving the efficiency and security of cryptocurrency transactions, making them more attractive to users.
#
# However, it's important to note that the cryptocurrency market is highly volatile and can be affected by a wide range of factors, including economic and political events, regulatory changes, and competition from other assets. Therefore, while I am confident in my prediction, there is always a degree of uncertainty involved in predicting the future price of Bitcoin or any other asset.

# %%
# Measuring accuracy of responds in historical data
invoke_llm("Predict the outcome of the 2016 United States presidential election. What was the probability of Donald Trump winning, and provide a confidence level for your prediction.")
invoke_llm("What was the likelihood of the Los Angeles Lakers winning the 2020 NBA Championship? Provide a probability score and a confidence level for your prediction.")
invoke_llm("As of the end of 2019, what was the probability of the US entering a recession in 2020? Provide a binary prediction, probability score, and confidence level.")
invoke_llm("As of the beginning of 2020, what was the likelihood of a COVID-19 vaccine being available for public use by the end of the year? Provide a binary prediction, probability score, and confidence level.")

# %%
for question, response in question_answers[7:]:
    print(f"Question: {question}")
    print(f"Answer:\n{response}")
    print("\n")
# Out:
# Question: What was the likelihood of the Los Angeles Lakers winning the 2020 NBA Championship? Provide a probability score and a confidence level for your prediction.
# Answer:
#
# {
# "yes": 0.7,
# "probability": 0.8,
# "confidence": 0.9
# }
#
# Based on my analysis of the Lakers' performance during the 2020 NBA season and their roster composition, I predict that they had a high likelihood (yes) of winning the championship. My probability score for this prediction is 0.8, indicating that there is an 80% chance that the Lakers will win the championship. My confidence level for this prediction is 0.9, indicating that I am very confident in my prediction.
#
# The Lakers had a strong roster with talented players such as LeBron James, Anthony Davis, and Danny Green, who are proven champions and have a track record of success in the NBA. They also had a well-balanced team with a good mix of veterans and young players, which allowed them to excel on both offense and defense. Additionally, they had a strong coaching staff led by Frank Vogel, who has a reputation for being a great tactician and motivator.
#
# However, it's important to note that the NBA is a highly competitive league with many talented teams, and there were other factors that could have affected the Lakers' chances of winning the championship. For example, the Boston Celtics had a strong roster as well and were also in contention for the championship. Additionally, injuries and COVID-related disruptions can always be a factor in any sports season.
#
# Despite these factors, I believe that the Lakers had a high likelihood of winning the championship based on their talent and roster composition. My prediction was correct as the Lakers went on to win the championship, defeating the Miami Heat in the NBA Finals.
#
#
# Question: As of the end of 2019, what was the probability of the US entering a recession in 2020? Provide a binary prediction, probability score, and confidence level.
# Answer:
#
# {
# "prediction": "yes",
# "probability_score": 0.7,
# "confidence_level": 90
# }
#
# Explanation:
# As of the end of 2019, the US economy was experiencing a slowdown in growth, with several indicators pointing to a potential recession in 2020. These indicators include:
#
# 1. Decreasing GDP growth rate: The US GDP growth rate has been steadily decreasing since Q2 2019, from 3.1% in Q2 to 2.1% in Q3 and 1.9% in Q4. This trend suggests that the economy is losing steam.
# 2. Decreasing consumer spending: Consumer spending, which accounts for over 70% of the US economy, has been steadily decreasing since Q2 2019. This decline could be a sign of reduced consumer confidence and lower spending.
# 3. Increasing unemployment claims: The number of unemployment claims has been increasing since Q4 2019, with over 250,000 claims filed in the last week of 2019 alone. This could be a sign of an impending recession.
# 4. Decreasing business investment: Business investment has been steadily decreasing since Q2 2019, with a 3.5% decrease in Q3 and a 4.6% decrease in Q4. This trend could indicate that businesses are becoming less optimistic about the future of the economy.
#
# Taking these factors into account, I predict with a high degree of confidence (90%) that the US will enter a recession in 2020. The probability score is 0.7, indicating a moderate likelihood of a recession occurring. However, it's important to note that these predictions are subject to change based on new data and developments.
#
#
# Question: As of the beginning of 2020, what was the likelihood of a COVID-19 vaccine being available for public use by the end of the year? Provide a binary prediction, probability score, and confidence level.
# Answer:
#
# {
# "prediction": "yes",
# "probability_score": 80,
# "confidence_level": 90
# }
#
# Based on the current state of COVID-19 vaccine development and clinical trials, it is highly likely (prediction: yes) that a COVID-19 vaccine will be available for public use by the end of 2020. The probability score of 80 indicates that there is an 80% chance of this prediction being correct, while the confidence level of 90 suggests that there is a high degree of certainty in this prediction.
#
# There are several factors that support this prediction:
#
# 1. Rapid progress in vaccine development: The COVID-19 pandemic has accelerated the development of vaccines, with multiple candidates already in various stages of clinical trials. This rapid progress suggests that a vaccine may be available sooner than anticipated.
# 2. Encouraging clinical trial results: Early results from clinical trials of COVID-19 vaccines have been promising, with some vaccines showing efficacy rates of up to 90% in preventing severe illness and death. While more testing is needed, these results suggest that a vaccine may be available by the end of 2020.
# 3. Increased funding and support: Governments and organizations around the world have allocated significant resources to develop and distribute COVID-19 vaccines. This increased funding and support is likely to accelerate the development process and make a vaccine available sooner.
# 4. Public health urgency: The COVID-19 pandemic has caused widespread illness and death, with significant economic and social impacts. The public health urgency of this crisis means that there is a strong incentive to develop and distribute a vaccine as quickly as possible.
#
# While there are still risks and uncertainties associated with the development and distribution of COVID-19 vaccines, the current trends and data suggest that it is highly likely (prediction: yes) that a vaccine will be available for public use by the end of 2020.
